# %%
import re
import os
import collections
import time
import json
import string

from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

import pandas as pd
import numpy as np

# This is the map where dictionary terms will be stored as keys and value will be posting list with position in the file
dictionary = {}
matrix = {}
# This is the map of docId to input file name
docIdMap = {}
kata = []
base = []
child = []
namaDokumen = ""

# %%
def proses_pertama(path):
    docId = 1
    """
            Membuat pengulangan sesuai jumlah data txt pada suatu folder
    """
    fileList = [f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))]
    print(fileList)
    fileobj = open('frekuensi.txt', 'w')
    for eachFile in fileList:
        position = 1
        count = 0
        """
        Di variable bawah ini nanti akan dimasukkan id File dan nama File txtnya
        """
        docIdMap[docId] = eachFile
        """
        DI variable bawah ini kita akan mendapatkan kalimat dari tiap barisnya
        """
        lines = [line.rstrip('\n') for line in open(path + "/" + eachFile)]
#         print(lines)        
#         print("================buat pengulangan")
        for eachLine in lines:
            """
                Di variable bawah ini kita akan memisahkan tiap kata-kata dalam 1 baris kalimat tersebut
            """
            """
            case folding
            """
            eachLine = eachLine.lower()
            eachLine = re.sub(r"\d+", "", eachLine)
            eachLine = eachLine.translate(str.maketrans("","",string.punctuation))
            #hapus simbol
            eachLine = re.sub('((www\.[^\s]+)|(https?://[^\s]+))',' ',eachLine)
            eachLine = re.sub('rt @[^\s]+',' ', eachLine)
            eachLine = re.sub('@[^\s]+',' ',eachLine)
            eachLine = re.sub(r'[^\x00-\x7F]+',' ', eachLine)
            #Remove additional white spaces
            eachLine = re.sub('[\s]+', ' ', eachLine)
            eachLine = re.sub(r'#([^\s]+)', r'\1', eachLine)
            eachLine = eachLine.strip()
            """
            stop words
            """
            stop_words = set(stopwords.words('english')) 
  
            word_tokens = word_tokenize(eachLine) 
            filtered_sentence = [w for w in word_tokens if not w in stop_words]
#             print(filtered_sentence)
#             wordList = re.split('\W+', eachLine)
#             while '' in wordList:
#                     wordList.remove('')
# #             print(wordList)
#             print("==========================================STEMMING")
            ps = PorterStemmer()
            for k in filtered_sentence:
                kata.append(ps.stem(k))
#             for word in filtered_sentence:
                word = ps.stem(k)
                if (word.lower() in dictionary):
                    postingList = dictionary[word.lower()]
                    if (docId in postingList):
                        postingList[docId].append(position)
                        position = position + 1
                    else:
                        postingList[docId] = [position]
                        position = position + 1
                else:
                    dictionary[word.lower()] = {docId: [position]}
                    position = position + 1
#             print("==========================================END")
                    
        docId = docId + 1
            
    length_dict = {key: len(value) for key, value in dictionary.items()}
#     print(len(dictionary['told']))
    for ae in dictionary['told']:
#         print(dictionary['told'][ae])
        for swx in docIdMap:
#             print("doc id"+str(sw))
#             print(str(ae))
            if (str(ae) == str(swx)):
                pass
#                 print("pada dok "+str(docIdMap[ae]) +" "+str(len(dictionary['told'][ae])))
#         print(ae)
#     print("tampil data")
#     print(docIdMap[1])
    for key in dictionary:
#         print(key)
        child.append(key)
#         for s, value in dictionary[key].items():
        for sw in docIdMap:
            pass
#             print(str(s))
#             if (str(s) not in docIdMap):
#                 print(0)
#             for sw2 not in docIdMap:
#                 print(str(sw2))
#             for sw in docIdMap:
            for s, value in dictionary[key].items():
                if (str(s) in str(sw)):
#                     print("pada dok "+str(sw) +" "+str(len(dictionary[key][s])))
                    child.append(len(dictionary[key][s]))
                    break
            else:
#                 print("pada dok gagal "+str(sw) +" 0")
                child.append(0)
        base.append(child)
#         child.clear()
#             print("line")
#             for i, value in dictionary[key][str(s)]:
#                 print(str(i))
        
            
        
           
    
#     a = pd.DataFrame(dictionary.items())
#     print(a)
    """
    Buat file
    """
    for w in length_dict:
        # ini nanti dibuat menangkap jumlah kata di suatu file txt
        # if str(w) == 'red':
        #     fileobj.write(w +"   |   "+str(length_dict[w]))
        #     fileobj.write("\n")
        fileobj.write(w +"   |   "+str(length_dict[w]))
        fileobj.write("\n")
    fileobj.close()
    print("================================================")
    print(dictionary)

# %%
def main():
    AlamatDir = "test"
    queryFile = "query"
    proses_pertama(AlamatDir)

# %%
if __name__ == '__main__':
    main()
# Out:
# ['data1.txt', 'data3.txt', 'data2.txt']
# ...

# %%
# data = [['worldcom', 8, 0, 0], ['boss', 4, 0, 0], ['left', 1, 0, 0], ['book', 2, 1, 0], ['alon', 1, 0, 0], ['former', 5, 2, 0], ['berni', 1, 0, 0], ['ebber', 7, 0, 0], ['accus', 1, 1, 0], ['overse', 1, 0, 0], ['bn', 6, 0, 0], ['£bn', 1, 1, 0], ['fraud', 3, 0, 0], ['never', 1, 0, 1], ['made', 2, 2, 1], ['account', 5, 0, 0], ['decis', 3, 0, 0], ['wit', 2, 0, 0], ['told', 4, 8, 2], ['juror', 1, 0, 0], ['david', 2, 1, 0], ['myer', 5, 0, 1], ['comment', 1, 1, 0], ['question', 1, 0, 0], ['defenc', 3, 0, 0], ['lawyer', 3, 1, 0], ['argu', 1, 3, 0], ['mr', 12, 31, 0], ['respons', 1, 2, 1], ['problem', 2, 1, 0], ['phone', 1, 0, 0], ['compani', 5, 0, 1], ['collaps', 4, 0, 0], ['prosecutor', 2, 0, 0], ['claim', 1, 5, 0], ['loss', 1, 0, 0], ['hidden', 1, 0, 0], ['protect', 1, 0, 0], ['firm', 11, 0, 0], ['share', 5, 0, 0], ['alreadi', 1, 2, 0], ['plead', 1, 0, 0], ['guilti', 2, 0, 0], ['assist', 1, 0, 2], ['monday', 1, 0, 0], ['reid', 1, 0, 0], ['weingarten', 2, 0, 0], ['tri', 3, 3, 1], ['distanc', 1, 0, 0], ['client', 1, 0, 0], ['alleg', 1, 0, 0], ['cross', 1, 0, 0], ['examin', 1, 0, 0], ['ask', 1, 4, 0], ['ever', 2, 1, 0], ['knew', 1, 0, 0], ['make', 2, 1, 2], ['awar', 1, 0, 0], ['repli', 2, 1, 0], ['know', 1, 4, 0], ['entri', 2, 0, 0], ['press', 1, 0, 0], ['admit', 3, 0, 0], ['order', 1, 2, 0], ['fals', 1, 0, 0], ['request', 1, 0, 0], ['chief', 2, 0, 0], ['financi', 5, 0, 0], ['offic', 1, 1, 3], ['scott', 1, 0, 0], ['sullivan', 2, 0, 0], ['paint', 1, 0, 0], ['testifi', 1, 0, 0], ['later', 1, 0, 1], ['trial', 2, 2, 2], ['mastermind', 1, 0, 0], ['behind', 2, 0, 1], ['hous', 1, 5, 0], ['card', 8, 1, 0], ['team', 1, 0, 0], ['meanwhil', 1, 0, 0], ['look', 1, 2, 1], ['portray', 1, 0, 2], ['affabl', 1, 0, 0], ['admiss', 1, 0, 0], ['pe', 1, 0, 0], ['graduat', 1, 0, 0], ['economist', 1, 0, 0], ['whatev', 1, 0, 0], ['abil', 2, 1, 0], ['transform', 1, 1, 1], ['rel', 1, 0, 1], ['unknown', 1, 1, 0], ['telecom', 2, 0, 0], ['giant', 1, 0, 0], ['investor', 2, 0, 0], ['darl', 1, 0, 0], ['late', 1, 1, 0], ['mount', 1, 0, 0], ['howev', 3, 0, 1], ['competit', 2, 0, 0], ['increas', 2, 1, 0], ['boom', 1, 0, 0], ['peter', 1, 2, 0], ['final', 1, 0, 3], ['sharehold', 4, 0, 0], ['lost', 2, 0, 0], ['worker', 1, 0, 0], ['job', 1, 0, 1], ['expect', 2, 2, 1], ['last', 4, 1, 3], ['two', 4, 1, 1], ['month', 2, 0, 0], ['found', 1, 0, 0], ['ceo', 1, 0, 0], ['face', 1, 4, 0], ['substanti', 1, 0, 0], ['jail', 1, 0, 0], ['sentenc', 1, 0, 0], ['firmli', 1, 0, 0], ['declar', 1, 0, 0], ['innoc', 1, 0, 0], ['virgin', 9, 0, 0], ['blue', 9, 0, 0], ['plummet', 1, 0, 0], ['australian', 1, 0, 0], ['budget', 2, 1, 0], ['airlin', 3, 0, 0], ['plung', 1, 0, 0], ['warn', 1, 1, 0], ['steep', 1, 0, 0], ['fall', 4, 0, 0], ['full', 2, 0, 0], ['year', 9, 4, 5], ['profit', 6, 0, 0], ['said', 7, 22, 11], ['tax', 1, 2, 0], ['march', 1, 0, 0], ['would', 4, 11, 4], ['lower', 2, 0, 0], ['previou', 1, 0, 1], ['sluggish', 1, 0, 0], ['demand', 5, 0, 0], ['report', 2, 1, 0], ['previous', 1, 0, 1], ['novemb', 3, 0, 0], ['decemb', 1, 0, 1], ['continu', 2, 2, 0], ['execut', 2, 0, 0], ['brett', 1, 0, 0], ['godfrey', 1, 0, 0], ['own', 3, 0, 0], ['richard', 1, 0, 0], ['branson', 1, 0, 0], ['struggl', 1, 0, 0], ['fend', 1, 0, 0], ['pressur', 1, 0, 0], ['rival', 3, 0, 0], ['jetstar', 2, 0, 0], ['cut', 5, 2, 0], ['passeng', 1, 0, 0], ['number', 1, 1, 3], ['forecast', 1, 0, 0], ['approxim', 1, 0, 0], ['first', 4, 1, 2], ['quarter', 1, 0, 0], ['august', 1, 0, 0], ['due', 2, 0, 1], ['tough', 1, 0, 0], ['half', 1, 0, 0], ['slack', 1, 0, 0], ['rise', 2, 0, 0], ['fuel', 2, 0, 0], ['cost', 1, 1, 0], ['launch', 1, 0, 0], ['four', 1, 1, 0], ['ago', 1, 1, 0], ['roughli', 1, 0, 1], ['one', 3, 3, 5], ['third', 1, 0, 2], ['australia', 1, 0, 0], ['domest', 1, 0, 0], ['market', 6, 0, 0], ['nation', 1, 5, 1], ['carrier', 1, 0, 0], ['qanta', 1, 0, 0], ['fought', 1, 0, 0], ['back', 2, 8, 1], ['took', 2, 0, 3], ['sky', 1, 0, 0], ['may', 3, 2, 3], ['sydneylist', 1, 0, 0], ['recov', 2, 0, 0], ['slightli', 1, 0, 0], ['close', 5, 1, 1], ['wednesday', 1, 1, 0], ['major', 1, 0, 1], ['patrick', 1, 0, 0], ['corpor', 1, 0, 0], ['drop', 1, 0, 1], ['crude', 5, 0, 0], ['oil', 7, 0, 0], ['price', 9, 0, 0], ['cold', 1, 0, 0], ['weather', 1, 1, 0], ['across', 1, 1, 1], ['part', 1, 3, 0], ['unit', 1, 0, 0], ['state', 1, 2, 0], ['much', 3, 1, 2], ['europ', 2, 0, 1], ['push', 1, 1, 0], ['us', 5, 2, 7], ['barrel', 4, 0, 0], ['time', 3, 2, 4], ['almost', 1, 1, 1], ['three', 1, 0, 3], ['freez', 1, 0, 0], ['temperatur', 2, 0, 0], ['heavi', 2, 0, 0], ['snowfal', 1, 0, 0], ['heat', 1, 0, 0], ['stock', 3, 0, 0], ['low', 3, 0, 0], ['fresh', 1, 0, 0], ['valu', 2, 1, 0], ['dollar', 4, 0, 0], ['help', 2, 3, 0], ['carri', 1, 0, 1], ['mark', 1, 1, 1], ['sinc', 1, 1, 0], ['new', 1, 4, 5], ['york', 1, 1, 4], ['tuesday', 2, 0, 0], ['opec', 3, 0, 0], ['member', 2, 1, 2], ['saw', 1, 1, 1], ['reason', 1, 0, 0], ['output', 1, 0, 0], ['although', 1, 0, 1], ['peak', 1, 0, 0], ['reach', 2, 0, 0], ['octob', 1, 0, 0], ['well', 1, 0, 0], ['averag', 1, 1, 0], ['brent', 1, 0, 0], ['also', 3, 8, 3], ['rose', 1, 0, 2], ['london', 1, 2, 0], ['trade', 1, 0, 0], ['ad', 2, 2, 2], ['western', 1, 0, 0], ['north', 1, 1, 0], ['east', 1, 0, 1], ['america', 1, 0, 0], ['shiver', 1, 0, 0], ['unseason', 1, 0, 0], ['recent', 1, 5, 0], ['day', 1, 3, 4], ['declin', 1, 0, 0], ['fiveweek', 1, 0, 0], ['euro', 1, 0, 0], ['serv', 1, 0, 0], ['inflat', 1, 0, 0], ['move', 2, 1, 1], ['sharpli', 1, 0, 0], ['overnight', 1, 0, 0], ['follow', 2, 0, 3], ['chri', 1, 0, 0], ['fur', 1, 0, 0], ['senior', 1, 2, 0], ['strategist', 1, 0, 0], ['cast', 1, 0, 1], ['weaken', 1, 0, 0], ['obvious', 1, 0, 0], ['higher', 3, 0, 0], ['sever', 2, 0, 0], ['product', 1, 0, 2], ['unlik', 1, 0, 0], ['cite', 1, 0, 0], ['strong', 1, 0, 1], ['asia', 1, 0, 0], ['agre', 2, 0, 0], ['need', 4, 3, 0], ['suppli', 2, 0, 0], ['fathi', 1, 0, 0], ['bin', 1, 0, 0], ['shatwan', 1, 0, 0], ['libya', 1, 0, 0], ['minist', 1, 4, 0], ['reuter', 2, 0, 0], ['think', 1, 0, 1], ['unless', 2, 1, 0], ['watch', 1, 0, 1], ['global', 1, 0, 0], ['ensur', 1, 0, 1], ['excess', 1, 0, 0], ['arriv', 1, 0, 0], ['spring', 1, 1, 0], ['northern', 1, 0
, 1, 1], ['subject', 0, 1, 0], ['curfew', 0, 1, 0], ['tag', 0, 1, 0], ['dub', 0, 1, 1], ['abus', 0, 2, 0], ['power', 0, 7, 0], ['sought', 0, 1, 0], ['deport', 0, 3, 0], ['detaine', 0, 2, 0], ['mainli', 0, 1, 0], ['held', 0, 2, 0], ['belmarsh', 0, 2, 0], ['prison', 0, 2, 0], ['current', 0, 3, 0], ['introduc', 0, 1, 0], ['effort', 0, 1, 0], ['origin', 0, 1, 1], ['algeria', 0, 1, 0], ['tunisia', 0, 1, 0], ['egypt', 0, 1, 0], ['jordan', 0, 1, 0], ['tortur', 0, 1, 0], ['death', 0, 1, 1], ['prompt', 0, 1, 0], ['british', 0, 4, 1], ['restrict', 0, 1, 1], ['movement', 0, 1, 1], ['limit', 0, 1, 0], ['telephon', 0, 1, 0], ['internet', 0, 1, 0], ['includ', 0, 1, 5], ['discriminatori', 0, 1, 0], ['intellig', 0, 1, 0], ['signific', 0, 1, 0], ['threat', 0, 2, 0], ['clive', 0, 1, 0], ['staffordsmith', 0, 1, 0], ['prosecut', 0, 1, 0], ['independ', 0, 1, 1], ['scrutini', 0, 1, 0], ['judg', 0, 2, 0], ['emerg', 0, 1, 0], ['prevent', 0, 1, 0], ['deter', 0, 1, 0], ['terrorist', 0, 3, 0], ['freed', 0, 1, 0], ['place', 0, 1, 1], ['consid', 0, 1, 0], ['wiretap', 0, 2, 0], ['intercept', 0, 3, 0], ['evid', 0, 5, 0], ['court', 0, 2, 0], ['refus', 0, 1, 0], ['small', 0, 1, 0], ['men', 0, 1, 2], ['sourc', 0, 1, 0], ['indefinit', 0, 1, 0], ['davi', 0, 1, 0], ['worri', 0, 1, 0], ['special', 0, 1, 0], ['throughout', 0, 1, 0], ['intern', 0, 1, 1], ['backfir', 0, 1, 0], ['resent', 0, 1, 0], ['process', 0, 1, 0], ['clearli', 0, 1, 0], ['confin', 0, 1, 0], ['recruit', 0, 1, 0], ['suggest', 0, 1, 0], ['let', 0, 1, 0], ['securityclear', 0, 1, 0], ['view', 0, 1, 0], ['gather', 0, 1, 0], ['phonetap', 0, 1, 0], ['democrat', 0, 1, 0], ['spokesman', 0, 1, 0], ['oaten', 0, 1, 0], ['standard', 0, 1, 0], ['proof', 0, 1, 0], ['inde', 0, 1, 0], ['fit', 0, 1, 0], ['shami', 0, 1, 0], ['chakrabarti', 0, 1, 0], ['liberti', 0, 1, 0], ['join', 0, 1, 1], ['adher', 0, 1, 0], ['game', 0, 1, 1], ['cat', 0, 1, 0], ['mous', 0, 1, 0], ['swap', 0, 1, 0], ['opt', 0, 1, 0], ['ocean', 0, 0, 5], ['twelv', 0, 0, 3], ['raid', 0, 0, 1], ['box', 0, 0, 3], ['caper', 0, 0, 1], ['sequel', 0, 0, 7], ['star', 0, 0, 10], ['clooney', 0, 0, 2], ['brad', 0, 0, 1], ['julia', 0, 0, 1], ['robert', 0, 0, 2], ['gone', 0, 0, 1], ['straight', 0, 0, 1], ['chart', 0, 0, 1], ['weekend', 0, 0, 2], ['ticket', 0, 0, 1], ['sale', 
], ['adventur', 0, 0, 1], ['babysit', 0, 0, 1], ['stephen', 0, 0, 1], ['adapt', 0, 0, 1], ['dead', 0, 0, 1], ['zone', 0, 0, 1], ['clue', 0, 0, 1], ['base', 0, 0, 1], ['board', 0, 0, 1], ['cluedo', 0, 0, 1], ['pursu', 0, 0, 1], ['la', 0, 0, 1], ['rubbl', 0, 0, 1], ['twin', 0, 0, 1], ['tower', 0, 0, 1], ['coproduc', 0, 0, 1], ['earli', 0, 0, 1]]
data = [child[i:i+4] for i in range(0, len(child),4)]
# data = base
kolom = []
p = []
kolom.append('Term / kata')
for x in docIdMap:
    p.append("Dokumen "+ str(x))
    kolom.append("Dokumen "+ str(x))
print(docIdMap)
# Create the pandas DataFrame 
df = pd.DataFrame(data, columns = kolom) 
df.sort_values(p, ascending=False)
# print dataframe. 
# print(pd.concat([pd.DataFrame({})] + [df], axis=1))
# Out:
# {1: 'data1.txt', 2: 'data3.txt', 3: 'data2.txt'}
#      Term / kata  Dokumen 1  Dokumen 2  Dokumen 3
# 26            mr         12          0          0
# 37          firm         11          0          0
# 121       virgin          9          0          0
# 122         blue          9          0          0
# 132         year          9          0          0
# ...          ...        ...        ...        ...
# 1284       rubbl          0          0          1
# 1285        twin          0          0          1
# 1286       tower          0          0          1
# 1287    coproduc          0          0          1
# 1288       earli          0          0          1
#
# [1289 rows x 4 columns]

# %%
# nyoba = []
p = 0
l = 0
nyoba = [child[i:i+4] for i in range(0, len(child),4)]
print(nyoba)
# Out:
# [['worldcom', 8, 0, 0], ['boss', 4, 0, 0], ['left', 1, 0, 0], ['book', 2, 1, 0], ['alon', 1, 0, 0], ['former', 5, 2, 0], ['berni', 1, 0, 0], ['ebber', 7, 0, 0], ['accus', 1, 1, 0], ['overse', 1, 0, 0], ['bn', 6, 0, 0], ['£bn', 1, 1, 0], ['fraud', 3, 0, 0], ['never', 1, 0, 1], ['made', 2, 2, 1], ['account', 5, 0, 0], ['decis', 3, 0, 0], ['wit', 2, 0, 0], ['told', 4, 8, 2], ['juror', 1, 0, 0], ['david', 2, 1, 0], ['myer', 5, 0, 1], ['comment', 1, 1, 0], ['question', 1, 0, 0], ['defenc', 3, 0, 0], ['lawyer', 3, 1, 0], ['argu', 1, 3, 0], ['mr', 12, 31, 0], ['respons', 1, 2, 1], ['problem', 2, 1, 0], ['phone', 1, 0, 0], ['compani', 5, 0, 1], ['collaps', 4, 0, 0], ['prosecutor', 2, 0, 0], ['claim', 1, 5, 0], ['loss', 1, 0, 0], ['hidden', 1, 0, 0], ['protect', 1, 0, 0], ['firm', 11, 0, 0], ['share', 5, 0, 0], ['alreadi', 1, 2, 0], ['plead', 1, 0, 0], ['guilti', 2, 0, 0], ['assist', 1, 0, 2], ['monday', 1, 0, 0], ['reid', 1, 0, 0], ['weingarten', 2, 0, 0], ['tri', 3, 3, 1], ['distanc', 1, 0,
# ...

# %%
a = pd.DataFrame(child)
print(a)
# Out:
#              0
# 0     worldcom
# 1            8
# 2            0
# 3            0
# 4         boss
# ...        ...
# 5159         1
# 5160     earli
# 5161         0
# 5162         0
# 5163         1
#
# [5164 rows x 1 columns]
